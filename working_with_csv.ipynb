# %%
import pandas as pd

# %% [markdown]
# opening a csv file from url

# %%
df = pd.read_csv("https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/main/day15%20-%20working%20with%20csv%20files/test.csv",header=1,index_col = "enrollee_id")
df
# Out:
#              0      city  city_development_index gender  \
# enrollee_id
# 29725        1   city_40                   0.776   Male
# 11561        2   city_21                   0.624    NaN
# 33241        3  city_115                   0.789    NaN
# 666          4  city_162                   0.767   Male
#
#                  relevent_experience enrolled_university education_level  \
# enrollee_id
# 29725         No relevent experience       no_enrollment        Graduate
# 11561         No relevent experience    Full time course        Graduate
# 33241         No relevent experience                 NaN        Graduate
# 666          Has relevent experience       no_enrollment         Masters
#
#             major_discipline experience company_size    company_type  \
# enrollee_id
# 29725                   STEM         15        50-99         Pvt Ltd
# 11561                   STEM          5          NaN             NaN
# ...

# %%
x = pd.read_csv("https://raw.githubusercontent.com/campusx-official/100-days-of-machine-learning/main/day15%20-%20working%20with%20csv%20files/aug_train.csv",chunksize = 5000)
for chunk in x:
    print(chunk.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (5000, 14)
# (4158, 14)
